# %% [markdown]
# # Public Debt Sustainability Analysis: an empirical approach for BRICS nations
#
# **Project for the 'Special Project in Economic Research' course**
#
# **By Luciana Dellome, Rhea Dhar, Anchit Goyal, Luis Ortega**
#
# *Jupiter notebook by Luis Ortega (work-in-progress, updated bi-weekly)*

# %% [markdown]
# **1. Abstract**

# %% [markdown]
# This paper carries out an empirical test for public debt sustainability in the BRICS nations. This work is part of an important literature on fiscal reaction functions and focuses on the response of primary balances to past public debt, with focus on BRICS nations. The paper utilizes a balanced panel with the 5 BRICS nations over 20 years and performs fixed effects. On the baseline work carried out in this notebook, the main finding is: BRICS nations public debt seems not sustainable, which requires specific attention and close analysis from policymakers. The paper acknowledges the need for further research on this topic, given its relevance in today’s economic context of rising interest rates.
#
# <ins> Note: on the complete version of the document, an additional novel contribution is made with the inclusion of natural disaster and political variables in the analysis. The objective of this notebook is to outlay the conceptual background, relevant data manipulation, and baseline results. </ins>

# %% [markdown]
# **2. Introduction**

# %% [markdown]
# Public Debt is considered sustainable, in broad terms, when a country can honor both in the short and long run, all its creditor’s claims and financial obligations without any need of financial assistance or going into default. From a conceptual point of view, sustainability of public debt can be guaranteed as long as the government upholds its intertemporal budget constraints.
#
# The accumulation of public debt has accelerated, especially in recent years, due to a sizeable fiscal expansion as a response to the COVID-19 pandemic, forcing governments to expand public spending beyond their budgetary limits. According to (Kose, Nagle, Ohnsorge, & Sugawara, 2021), the largest debt buildup (public and private) in many decades, is being observed now. The authors mention as examples: the 1970s and 1980 governments’ debt expansion in Latin America and Low-Income Countries and the crisis and default episodes following; the 1990s and early 2000s in East Asia and Pacific (EAP) with serial economic crisis between 1997-2001; and the Europe and Central Asia (ECA) wave of debt accumulation that resulted in the 2008 crisis. Attention is called to the fact that in 2020 total global debt achieved 263% of GDP, an increase of 30 percentage points, the largest single-year increase since 1970.
#
# In this context, as stressed by the IMF, <i> “Public debt as a ratio of GDP soared across the world during COVID-19 and is expected to remain elevated, posing a growing challenge for policymakers, particularly as interest rates are rising across the world” </i> (International Monetary Fund, 2023).
#
# Amid such economic reality, we focus on the analysis of BRICS nations (Brazil, Russia, India, China and South Africa) and the sustainability of their public debt. These countries represent approximately 31% of the world’s GDP per capita in PPP (up from 18% back in 2000), and account for 40% of the global population. More specifically, these countries are among the most relevant within emerging markets and developing economies, and also happen to show one of the largest debt accumulations in the past years.

# %% [markdown]
# **3. Literature Review**

# %% [markdown]
# *3.1 Theoretical underpinnings of public debt sustainability*
#
# The theoretical frameworks under which public debt sustainability has been analyzed have evolved during the past decades. On the one hand, the accounting-based approach for public debt sustainability requires an understanding of the intertemporal government budget constraint (IGBC) and the associated debt dynamics. (Willems & Zettlemeyer, 2022) provide insights on such analysis, and note that: (i) when solving the government budget constraint equation for the debt-to-GDP ratio, the result states that today’s debt must equal the discounted terminal debt plus the discounted present value of primary balances (notably, surpluses) on the analyzed horizon, and (ii) “there are two ways of operationalizing the broad, quantitative definitions of policy and debt sustainability”, one is the classic version in which the IGBC must hold, which requires no-Ponzi schemes, and the other is one that requires that current and projected future policies do not lead to an exploding debt ratio. As the authors mention, a context in which, at least on average, the government real borrowing rates are higher than the country’s real growth rate (r>g) is deemed relevant under this classical approach.
#
# In contrast to the classical approach to public debt sustainability, (Blanchard, 2019) explores the context of low interest rates and public debt. The lecture focuses on the welfare costs of higher public debt in specific contexts of interest rate and growth, with a concrete mention to the relevant dynamics between the safe rate and the marginal product in the overall welfare of the economy. In addition, he shows that for the US the environment of safe rates that remain below growth rates (arguably, r<g) is more the norm than the exception. Under such context, and to the provocation of many economists, with  r<g on average <i> “higher debt might not imply fiscal costs” </i>. It should be noted that (Blanchard, 2019) does not claim that this environment does not make any fiscal policy sustainable.
#
# Lastly, recent work from (Reis, 2022) explores the concept of Debt Revenue as an alternative to the traditional public debt sustainability analysis framework. In the author’s words, <i> “Since, for some reason, people are willing to hold public debt in spite of it giving a lower return than the private market alternative, their opportunity cost of doing so is a form of revenue for the government. Supplying public debt is providing some service to these investors. (…).” </i> The introduction of the marginal product of capital changes the typical budget constraint, and the result is an additional term which accounts for these ‘premiums’ between the marginal product of capital and the return of government bonds. Importantly, the results from (Reis, 2022) do acknowledge some difficult on measuring the marginal product of capital and proves alternative approaches, but it notes the need to consider the Debt Revenue dynamics for policymakers given its implications for public debt sustainability analysis.

# %% [markdown]
# *3.2 Empirical Debt Sustainability Tests*
#
# The most important paper in terms of content and academic basis to this research is The Behavior of U.S. Public Debt and Deficits (Bohn, 1998). Bohn’s idea was to investigate how governments react to expansion of debt and he used U.S. data from 1916-1995 in his analysis of how responsive the fiscal results were to a debt accumulation process. The author criticizes the stationarity tests and co-integration tests used so far to measure public debt governance and proposes a new test on debt sustainability. Through his study, the author shows that U.S. presents a mean-reverting tendency and the tests adopted in the previous literature for debt sustainability fail to reveal omitted variables bias and provide unreliable estimates.
#
# This test states that public debt is sustainable if the noninterest budget surplus/GDP is a positive function of the debt–GDP ratio. The economic intuition behind this regression is that if we have a scenario in which the level of debt is increasing, the government will react by aiming for a positive or higher primary result to avoid any fiscal imbalance which can turn the debt management into an uncontrollable situation. One interesting aspect of this sustainability test is that it does not require any interest rate assumptions.
#
# Following the work from Bohn, a wide application in terms of time periods and regions has been made. This is part of the growing literature regarding the Fiscal Reaction Function (FRF). Among many we can mention <i> Debt sustainability and the fiscal reaction function: evidence from MIST countries </i> (Ogbeifun & Shobande, 2020) in which the authors analyzed the relationship between primary balance in MIST countries (Mexico, Indonesia, South Korea, and Turkey) and public debt using a panel dataset from 1990 through 2017 to explore how sustainable fiscal policy in those economies were. In their fixed-effect regression and feasible generalized least squares estimations models they included primary balance as a dependent variable, lagged of debt-to-GDP ratio as the independent variable, interest payment on the public debt, current account balance, a business cycle variable- derived from the GDP series, an election year dummy and lagged primary balance as additional control variables. They observed that in MIST countries, <i> “primary balance improves by about 0.005–0.013 for every 1 percentage point increase in central government debt after controlling for other relevant factors” </i>. The study concluded with a recommendation to increase tax base revenue and reduce fiscal expenditure across MIST (Ogbeifun & Shobande, 2020).
#
# Another research work that influenced our choice for the fiscal reaction function was an empirical analysis of sustainability of public debt among BRICS nations (Joy & Panda, 2020) that besides developing a version of the FRF also investigated this relationship among BRICS economies during the years 1980–2017. Their model estimated the impact of variables like dummies of election year, ideology of the government and unemployment on primary surplus. Furthermore, a structural change dummy was included to measure how debt progression is affected by the 2008 financial crisis. With the result being a positive, albeit small, significant coefficient, it was observed that the primary balance for BRICS improves when the debt to GDP ratio increases in the region as a whole. <i> “This suggests that though the public debt is sustainable for BRICS, it is not strong enough. Small size of coefficient means sustainability is negligible. China and India have better public debt sustainability levels compared to Brazil, Russia, and South Africa.” </i> (Joy & Panda, 2020). When unemployment rises in BRICS the fiscal reaction is weakened, diminishing the response of primary balance to increase in debt, especially after the 2008 crisis. Regarding the political variables, it was noticeable that <i> “election year is negatively affecting sustainability since during election years governments take more liberal public spending and populist measures by using borrowed fund” </i> (Joy & Panda, 2020). Governments with weak coalitions tended to present less effective fiscal reactions and those who presented a more “centrist” political ideology showed a positive coefficient, even though it was not statistically significant, giving evidence that a more balanced power structure enables better fiscal management.

# %% [markdown]
# *3.3 Public Debt Dynamics*
#
# An initial consideration to have regarding public debt and its sustainability is understanding public debt dynamics. On one hand, as mentioned previously, one can infer the evolution of public debt (and its sustainability) directly from an inspection of the government budget constraint for a specific period. On the other hand, on a more comprehensive framework, public debt dynamics can be analyzed as a decomposition of changes in public debt in response to more interesting underlying macroeconomic factors. Unfortunately, there is no clear formula that allows a clean additive decomposition of changes in the debt ratio into the most interesting underlying factors, such as interest rates, inflation, fiscal adjustments, etc. (Escolano, 2010). Nonetheless, the IMF does provide guidance on the Sovereign Risk and Debt Sustainability Framework (SRDSF) for market access countries  which can be helpful to understand the evolution of public debt as a reflection of movements in key macroeconomic variables (drivers), along with the inclusion of realism tools to evaluate the realism of baseline economic forecasts, as well as near-term, medium-term, and long-term risk assessments tools. Following the IMF (International Monetary Fund, 2022), public debt in one year can be related to the previous year’s debt, the interest bill, the primary balance, and other factors in stock-flow adjustment.
#
# Importantly, from this analysis we can find an expression for the debt-stabilizing primary balance (assuming no changes in public debt, as well as no stock-flow adjustments and other potential transformations to the equation). From an empirical point of view, this enables a tool to discuss public debt sustainability on the basis of macroeconomic variables, as well as other variables of interest which could affect the ‘stock-flow’ adjustments.

# %% [markdown]
# *3.4 Public Debt and Crises*
#
# The mention of public debt dynamics is key to understanding the more concrete and broadly studied topics of public debt, sovereign default, and economic crises. One of the most prominent pieces of work on this topic is that carried out by Carmen Reinhart and Kenneth Rogoff in their book ‘This time is different: Eight Centuries of Financial Folly’. In their words <i> “This book provides a quantitative history of financial crises in their various guises. Our basic message is simple: We have been here before. (…), we study a number of different types of financial crises. They include sovereign default, which occur when a government fails to meet payments on its external or domestic debt obligations or both.” </i> (Reinhart & Rogoff, This time is different: Eight Centuries of Financial Folly, 2009).
#
# For the current paper’s purpose, we look at similar work from the authors which analyzes the dynamics between external debt, banking crises and public debt surges. Among other important findings, the authors note that: (i) <i> “domestic banking crises help to explain sovereign default,” </i> and (ii) <i> “surges in public debt have the expected significant positive effect on the likelihood of default” </i> (Reinhart & Rogoff, From Financial Crash to Debt Crises, 2011). These results support the need to preemptively analyze the dynamics of public debt in countries across the world in the context where potential crises could unfold. In addition, the de-facto default on sovereign debt is also deeply related to public debt sustainability: for the intertemporal government budget constraint to hold, either expected primary balances are required to adapt to sustain a specific public debt level, or the existing public debt level must decrease, which implies the occurrence of sovereign default.
#
# In addition to the literature studying the relationship between public debt and crisis, there is vast literature that analyses the determinants of sovereign default. One of the objectives of this literature is to identify a series of early warning indicators that can be used to predict default episodes (Panizza, Sturzenegger, & Zettlemeyer, 2012). For instance, (Ghulam & Derber, 2018) describe research by (Manasse & Roubini, 2009) in which they <i> “use a classification and regression tree (CART) methodology on a panel dataset including 47 market economics from 1970 to 2002” </i>. (Manasse & Roubini, 2009) find ten variables as sufficient for the classification or prediction of sovereign default: (i) external debt to GDP ratio, (ii) short-term debt reserves ratio, (iii) real GDP growth, (iv) public external debt/fiscal revenues ratio, (v) CPI inflation, (vi) number of years to the next presidential election, (vii) US treasury bills rate, (viii) external financial requirements, which consists of current account balance plus short term debt as a ratio of foreign reserves, (ix) exchange rate overvaluation, and (x) exchange rate volatility. This framework of analyzing sovereign default as a binary event that responds to macroeconomic factor mirrors that of analyzing public debt dynamics, and therefore is directly linked to public debt sustainability. Lastly, on a related note (Martinez, Roch, Roldan, & Zettlemeyer, 2022) survey the literature on sovereign debt from the perspective of understanding how sovereign debt differs from privately issued debt, and why sovereign debt is deemed safe in some countries but risky in others.

# %% [markdown]
# **4. Data and Methodology**

# %% [markdown]
# *4.1 Data*
#
# The main source of data this paper leverages on is the World Economic Outlook (WEO) Database of April 2023, which composes of a large selection of annual macroeconomic variables (GDP, Inflation, Fiscal Variables, among others) for most countries of the world, from 1980 until the most recent estimates for each country. This database is part of a bi-annual WEO survey (published in April and September/October) published by the International Monetary Fund, where it presents IMF’s staff economists’ analyses of global economic development during the near and medium-term.
#
# Note 1: The IMF includes 5-year ahead forecasts for most countries and macroeconomic variables, but these are not considered given the scope of the analysis.
#
# Note 2: The WEO Database does also include estimations of the output gap for several countries. However, for most years and most countries there is no estimation of the output gap. An output gap is calcualted for the relevant countries applying an HP filter to GDP at constant prices, in national currency.

# %% [markdown]
# *4.2 Model and Methodology*
#
# As part of the already existing literature on debt sustainability analysis and its frameworks, the model starts based on the work from (Bohn, 1998), where the author intends to search for a systematical relationship between the debt-income ratio and the primary balance. This framework is part of the literature which estimates fiscal reaction functions, and empirically (Bohn, 1998) estimates a regression of the form:
#
# $$
# \begin{align}
# pb_t= \theta d_t + \alpha Z_t + \epsilon_t
# \end{align}
# $$
#
# Where $pb_t$ is the ratio of primary balance to GDP in period t, $d_t$ is the (start-of-period) public debt to GDP ratio, $Z_t$ is a set of other determinants of primary surplus, and $\epsilon_t$ is an error term. As mentioned by (Bohn, 1998), this framework raises questions about the time series properties of the primary balance and public debt; if $pb_t$ and $d_t$ do not have unit roots, a simple regression of $pb_t$ on $d_t$ only will produce inconsistent estimates due to omitted variable bias. Importantly, $\theta$ is the coefficient of interest, as it measures the responsiveness of the primary balance to the debt ratio. It should also be noted that <i> “While Bohn shows that a sufficient condition for the government to satisfy its intertemporal budget constraint is that the primary balance always reacts positively to lagged debt, this can be thought of as a weak sustainability criterion that does not, for example, rule out an ever-increasing debt-to-GDP ratio (and thus the need for a primary surplus that eventually exceeds GDP)” </i> (Ghosh, Kim, Mendoza, Ostry, & Qureshi, 2013).
#
# This paper’s empirical model for this paper is an extension of the previous relationship. Following the work of (Ogbeifun & Shobande, 2020) we have
#
# $$
# \begin{align}
# pb_{i,t}= \alpha + \delta pb_{i,t-1} + [\theta d_{i,t-1}] + [\beta X_{i,t}]+ [\omega Z_{i,t}] + \gamma_i + \lambda_t + \epsilon_{i,t}
# \end{align}
# $$
#
# As mentioned before, $pb_{i,t}$ is the primary balance to GDP ratio for country i at time t, $d_{i,t-1}$ is the 1-year lagged debt-to-GDP ratio, $X_{i,t}$ is a vector key macro  determinants of the primary balance, $Z_{i,t}$ is a vector of natural disaster and political stability variables, $\gamma_i$ are country fixed effects, $\lambda_t$ are time dummies, and $\epsilon_{i,t}$ is the error term. Like (Ogbeifun & Shobande, 2020), this paper’s choice for the macro determinants of the primary balance follows the work from (Abiad & Baig, 2005). The base specification for the fiscal reaction function includes the lagged primary balance to GDP ratio and lagged public debt-to-GDP ratio. As for the other determinants of the primary balance, we include: (i) interest payments on public debt, (ii) the current account balance, (iii) the output gap (as our business cycle indicator variable), (iv) headline inflation, and (v) the election year dummy.
#
# Note: in the current versionof the notebook, the $Z_{i,t}$ variables have not been added yet.
#
# Given Bohn’s annotation regarding the time series properties of the variables, this paper applies second-generation panel data unit root tests to evaluate the order of integration of the variables in the model, since these tests tolerate cross-sectional dependence (Pesaran, 2007). Importantly, we acknowledge the dynamic panel data structure of the empirical model being utilized. However, given the structure of our panel data, our time dimension is reasonably larger than our cross-sectional dimension, by which we argue that any potential bias on the auto-regressive parameter would be negligible (Bond, 2002), especially in cases where the time series properties our variables show very low persistence. Lastly, this paper runs a Feasible GLS to account for any heteroscedasticity and cross-sectional dependence problems.
#
# <ins> In what follows of the jupiter notebook, the code used for data manipulation is presented. </ins>

# %%
#!pip install linearmodels

# %%
import pandas as pd
import numpy as np
import statsmodels as sm
from statsmodels.tsa.filters.hp_filter  import hpfilter
import matplotlib.pyplot as plt
from linearmodels import PanelOLS
from linearmodels import RandomEffects

# %matplotlib inline

# %%
#Reading the raw database and baseline adjustments (dropping last column, non-informative observations, etc)
weo = pd.read_csv('WEO_Data_Apr23.csv', thousands = ',', decimal = '.').drop('Estimates Start After', axis = 1)

#Re-ordering the columns in the database
weo['Variable'] = weo['Subject Descriptor'] + "_" + weo['Units']
temp_cols = weo.columns.tolist()
index = weo.columns.get_loc('Variable')
new_cols = temp_cols[0:1] + temp_cols[index:index+1] + temp_cols[2:index] + temp_cols[index+1:]

#Dropping extra columns
weo = weo[new_cols].drop(['Units', 'Scale', 'Country/Series-specific Notes'], axis = 1)

#Dropping footnotes and empty row, as well as replacing '--' for NaN (later, most of the NaN will be dropped)
weo = weo.drop(index = [8624,8625])
weo = weo.replace('--', np.nan)

# %%
#Given the use of comma's, I remove their use for thousands indicators and convert all the data back to float.
#This is useful for the future use of the HPFilter (it would not recongize a number like '1,319.900' as a float)
num_weo = weo.copy()

#Creating a string list of the years
years = list(range(1980,2029))
years_str = [str(x) for x in years]

#Replacing the commas
for x in years_str:
    num_weo[x] = weo[x].str.replace(',','')
    num_weo[x] = pd.to_numeric(num_weo[x], errors = 'coerce').astype('float64')
    
num_weo
# Out:
#           Country                                           Variable   1980  \
# 0     Afghanistan  Gross domestic product, constant prices_Nation...    NaN
# 1     Afghanistan  Gross domestic product, constant prices_Percen...    NaN
# 2     Afghanistan  Gross domestic product, current prices_Nationa...    NaN
# 3     Afghanistan  Gross domestic product, current prices_U.S. do...    NaN
# 4     Afghanistan  Gross domestic product, current prices_Purchas...    NaN
# ...           ...                                                ...    ...
# 8619     Zimbabwe    General government gross debt_National currency    NaN
# 8620     Zimbabwe       General government gross debt_Percent of GDP    NaN
# 8621     Zimbabwe  Gross domestic product corresponding to fiscal...    NaN
# 8622     Zimbabwe               Current account balance_U.S. dollars -0.301
# 8623     Zimbabwe             Current account balance_Percent of GDP    NaN
#
# ...

# %%
#Transforming the database to a panel-like structure
melt_weo = num_weo.set_index(['Country', 'Variable'])
stacked_weo = melt_weo.stack(dropna = False).reset_index()
stacked_weo.columns = ['Country', 'Variable', 'Year','Value']
stacked_weo['Year'] = stacked_weo['Year'].astype(int) #Turning the years used back to Integer
pivoted_weo = stacked_weo.pivot(index = ['Country', 'Year'], columns = 'Variable', values = 'Value')
original_columns = list(pivoted_weo.columns)
pivoted_weo
# Out:
# Variable          Current account balance_Percent of GDP  \
# Country     Year
# Afghanistan 1980                                     NaN
#             1981                                     NaN
#             1982                                     NaN
#             1983                                     NaN
#             1984                                     NaN
# ...                                                  ...
# Zimbabwe    2024                                   0.762
#             2025                                   0.714
#             2026                                   0.646
#             2027                                   0.578
#             2028                                   0.515
#
# Variable          Current account balance_U.S. dollars  Employment_Persons  \
# Country     Year
# Afghanistan 1980                                   NaN                 NaN
#             1981                                   NaN                 NaN
# ...

# %%
#Renaming the variables from the database for easier tractability
#General guidelines: _GDP = 'As a percentage of GDP' or _PGDP = 'As a percentage of potential GDP', '_USDB = in USD billions', '_Persons removed, implied millions', '_National currency = nominal, as in expressed as local currency', _2017PPP = '2017 international dollars PPP'
weo_df = pivoted_weo.rename(columns = {"Current account balance_Percent of GDP": "CAB_GDP", "Current account balance_U.S. dollars": "CAB_USDB", \
                                       "Employment_Persons": "Employment", \
                                       "General government gross debt_National currency": "Public Debt_nominal", "General government gross debt_Percent of GDP": "Public Debt_GDP", \
                                       "General government net debt_National currency": "Net Public Debt_nominal", "General government net debt_Percent of GDP": "Net Public Debt_GDP", \
                                       "General government net lending/borrowing_National currency": "Economic result_nominal", "General government net lending/borrowing_Percent of GDP": "Economic result_GDP", \
                                       "General government primary net lending/borrowing_National currency": "Primary balance_nominal", "General government primary net lending/borrowing_Percent of GDP": "Primary balance_GDP", \
                                       "General government revenue_National currency": "Fiscal revenue_nominal", "General government revenue_Percent of GDP": "Fiscal revenue_GDP", \
                                       "General government structural balance_National currency": "Structural result_nominal", "General government structural balance_Percent of potential GDP": "Structural result_PGDP", \
                                       "General government total expenditure_National currency": "Government spending_nominal", "General government total expenditure_Percent of GDP": "Government spending_GDP", \
                                       "Gross domestic product based on purchasing-power-parity (PPP) share of world total_Percent": "share of world GDP in PPP", \
                                       "Gross domestic product corresponding to fiscal year, current prices_National currency": "FY GDP_nominal", \
                                       "Gross domestic product per capita, constant prices_National currency": "GDP per capita_constant_national", \
                                       "Gross domestic product per capita, constant prices_Purchasing power parity; 2017 international dollar": "GDP per capita_constant_2017PPP", \
                                       "Gross domestic product per capita, current prices_National currency": "GDP per capita_current_national", \
                                       "Gross domestic product per capita, current prices_Purchasing power parity; international dollars": "GDP per capita_current_PPP", \
                                       "Gross domestic product per capita, current prices_U.S. dollars": "GDP per capita_current_USD", \
                                       "Gross domestic product, constant prices_National currency": "GDP_constant_national", \
                                       "Gross domestic product, constant prices_Percent change": "real GDP growth", \
                                       "Gross domestic product, current prices_National currency": "nominal GDP", \
                                       "Gross domestic product, current prices_Purchasing power parity; international dollars": "GDP_current_PPP", \
                                       "Gross domestic product, current prices_U.S. dollars": "nominal GDP_USD", \
                                       "Gross domestic product, deflator_Index": "GDP deflator", \
                                       "Gross national savings_Percent of GDP": "national savings_GDP", \
                                       "Implied PPP conversion rate_National currency per current international dollar": "implied PPP_current", \
                                       "Inflation, average consumer prices_Index": "Avg CPI", \
                                       "Inflation, average consumer prices_Percent change": "Avg Inflation", \
                                       "Inflation, end of period consumer prices_Index": "EoP CPI", \
                                       "Inflation, end of period consumer prices_Percent change": "Inflation", \
                                       "Output gap in percent of potential GDP_Percent of potential GDP": "Output gap", \
                                       "Population_Persons": "Population", \
                                       "Total investment_Percent of GDP": "Investment_GDP", \
                                       "Unemployment rate_Percent of total labor force": "Unemployment", \
                                       "Volume of Imports of goods_Percent change": "Real good imports change", \
                                       "Volume of imports of goods and services_Percent change": "Real imports change", \
                                       "Volume of exports of goods_Percent change": "Real good exports change", \
                                       "Volume of exports of goods and services_Percent change": "Real exports change"
                                      })
weo_df
# Out:
# Variable          CAB_GDP  CAB_USDB  Employment  Public Debt_nominal  \
# Country     Year
# Afghanistan 1980      NaN       NaN         NaN                  NaN
#             1981      NaN       NaN         NaN                  NaN
#             1982      NaN       NaN         NaN                  NaN
#             1983      NaN       NaN         NaN                  NaN
#             1984      NaN       NaN         NaN                  NaN
# ...                   ...       ...         ...                  ...
# Zimbabwe    2024    0.762     0.203         NaN            103677.33
#             2025    0.714     0.200         NaN            218327.92
#             2026    0.646     0.184         NaN            380726.41
#             2027    0.578     0.154         NaN            570213.48
#             2028    0.515     0.143         NaN            657074.07
#
# Variable          Public Debt_GDP  Net Public Debt_nominal  \
# Country     Year
# ...

# %%
#Creating the relevant variables from the available database

#Creating the Interest payment variable (as a percentage of GDP)
weo_df['Interest_GDP'] = weo_df['Primary balance_GDP'] - weo_df['Economic result_GDP']

#Creating the lag of primary balance
weo_df['Primary Balance Lag'] = weo_df['Primary balance_GDP'].shift(1) 

#Creating the lag of public debt
weo_df['Public Debt Lag'] = weo_df['Public Debt_GDP'].shift(1)

#Creating the square of lagged public debt
weo_df['Public Debt Lag Sq'] = weo_df['Public Debt Lag']**2

weo_df[['Interest_GDP', 'Primary Balance Lag', 'Public Debt Lag', 'Public Debt Lag Sq']]
# Out:
# Variable          Interest_GDP  Primary Balance Lag  Public Debt Lag  \
# Country     Year
# Afghanistan 1980           NaN                  NaN              NaN
#             1981           NaN                  NaN              NaN
#             1982           NaN                  NaN              NaN
#             1983           NaN                  NaN              NaN
#             1984           NaN                  NaN              NaN
# ...                        ...                  ...              ...
# Zimbabwe    2024         0.134               -2.831          102.335
#             2025         0.125               -2.100           99.958
#             2026         0.118               -2.092           90.857
#             2027         0.115               -2.092           83.454
#             2028         0.108               -2.076           83.553
#
# Variable          Public Debt Lag Sq
# Country     Year
# Afghanistan 1980                 NaN
# ...

# %%
#As part of the literature, the Output Gap must be calculated for each country.
#Even though the WEO database has an output gap estimate for some countries, an 'own' estimate is created for available data.
#An HP filter is applied to national currency constant prices GDP for each country for all years available.
#2022 and future forecast years are excluded since most countries have estimates for such years.

#Extracting real GDP (levels)
gdp = weo_df[['GDP_constant_national']].copy()
gdp = gdp.reset_index()

#Reshaping the data to have a standard structure (years as rows, countries as columns), and dropping 2022 and onwards
output = gdp.groupby(['Year', 'Country'])['GDP_constant_national'].sum().unstack()
output = output.replace(0, np.nan).dropna(axis = 1, how = "all")
output = output.drop([2022, 2023, 2024, 2025, 2026, 2027, 2028], axis = 0)
print(output)
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra    Angola  \
# Year
# 1980             NaN  311.514  2596.37      NaN   210.654
# 1981             NaN  329.270  2674.26      NaN   201.385
# 1982             NaN  338.819  2845.41      NaN   201.385
# 1983             NaN  342.546  2999.06      NaN   209.843
# 1984             NaN  349.397  3167.01      NaN   222.434
# 1985             NaN  344.156  3344.36      NaN   230.219
# 1986             NaN  363.428  3337.68      NaN   236.895
# 1987             NaN  360.521  3314.31      NaN   246.567
# 1988             NaN  355.474  3251.34      NaN   261.679
# 1989             NaN  390.310  3407.40      NaN   261.788
# 1990             NaN  351.279  3434.66      NaN   252.756
# 1991             NaN  252.921  3393.45      NaN   283.298
# 1992             NaN  234.711  3447.74      NaN   315.601
# 1993             NaN  257.243  3375.25      NaN   350.220
# 1994             NaN  281.424  3344.88      NaN   387.031
# ...

# %%
#Applying the HP Filter to each country
output_cycle_list = []
output_trend_list = []
for col in output.columns:
    country_data = output[col].dropna()
    cycle, trend = hpfilter(country_data, lamb = 100) #If the values of Ravn and Uhlig want to be used, the lamb value can be adjusted
    cycle.name = col.replace('_cycle', '')
    trend.name = col.replace('_trend', '')
    output_cycle_list.append(cycle)
    output_trend_list.append(trend)
    
#Creating a mapper for the new output gap
keys = range(0,195) #the 195 comes from the fact that there are 194 countries in the database.
values = list(output.columns)
map = dict(zip(keys, values))

#Creating the cycle dataframe
d_cycle = dict(enumerate(output_cycle_list))
df_cycle = pd.DataFrame(d_cycle)
df_cycle = df_cycle.rename(map, axis = 'columns')

#Creating the trend dataframe
d_trend = dict(enumerate(output_trend_list))
df_trend = pd.DataFrame(d_trend)
df_trend = df_trend.rename(map, axis = 'columns')

#Calculating the output gap
output_gap = df_cycle.div(df_trend)*100

#Visualizing the output gap dataframe
print(output_gap)
# Out:
#       Afghanistan    Albania   Algeria    Andorra     Angola  \
# Year
# 1980          NaN  -7.255915 -4.242411        NaN   9.438492
# 1981          NaN  -2.564493 -4.605108        NaN   1.649768
# 1982          NaN  -0.272094 -1.684642        NaN  -1.247273
# 1983          NaN   0.460327  0.592896        NaN  -0.139716
# 1984          NaN   2.373704  3.426747        NaN   2.537407
# 1985          NaN   1.110163  6.729061        NaN   2.550367
# 1986          NaN   7.529978  4.499950        NaN   1.641330
# 1987          NaN   7.974793  2.172633        NaN   1.486356
# 1988          NaN   8.319180 -1.024258        NaN   2.825313
# 1989          NaN  21.542263  2.633719        NaN  -2.333018
# 1990          NaN  12.101689  2.497512        NaN -11.019598
# 1991          NaN -17.381784  0.365405        NaN  -6.477839
# 1992          NaN -22.052736  0.980514        NaN  -2.801812
# 1993          NaN -14.090148 -2.294601        NaN   0.273719
# ...

# %%
#Going back to the panel-like structure
stacked_gap = output_gap.stack(dropna = False).reset_index()
stacked_gap.columns = ['Year', 'Country', 'Output_Gap']
stacked_gap = stacked_gap.set_index(['Country', 'Year']).sort_values(['Country', 'Year']) #Relevant to set the outer index as entity, and inner as time.

stacked_gap
# Out:
#                   Output_Gap
# Country     Year
# Afghanistan 1980         NaN
#             1981         NaN
#             1982         NaN
#             1983         NaN
#             1984         NaN
# ...                      ...
# Zimbabwe    2017    5.569765
#             2018    8.117258
#             2019   -0.386513
#             2020   -9.701045
#             2021   -3.625608
#
# [8190 rows x 1 columns]

# %%
#Merging the databases back to the complete database
weo_df = weo_df.merge(stacked_gap, how = 'left', on = ['Country', 'Year'])

#A look at the full database
weo_df
# Out:
#                   CAB_GDP  CAB_USDB  Employment  Public Debt_nominal  \
# Country     Year
# Afghanistan 1980      NaN       NaN         NaN                  NaN
#             1981      NaN       NaN         NaN                  NaN
#             1982      NaN       NaN         NaN                  NaN
#             1983      NaN       NaN         NaN                  NaN
#             1984      NaN       NaN         NaN                  NaN
# ...                   ...       ...         ...                  ...
# Zimbabwe    2024    0.762     0.203         NaN            103677.33
#             2025    0.714     0.200         NaN            218327.92
#             2026    0.646     0.184         NaN            380726.41
#             2027    0.578     0.154         NaN            570213.48
#             2028    0.515     0.143         NaN            657074.07
#
#                   Public Debt_GDP  Net Public Debt_nominal  \
# Country     Year
# ...

# %%
#Finally, we start subsetting the database to contain the relevant years, countries and variables to carry out the analysis.
#First, we drop all the rows for which we do not have information for any variable
df = weo_df.dropna(axis = 0, how = 'all')
#Second, we drop all the rows for which IMF forecasts are included, so the database contains (where possible) no estimates
df = df.drop(index = [2022, 2023, 2024, 2025, 2026, 2027, 2028], level = 'Year')
#Third, we keep variables which will be used in the analysis given the existing literature
df = df[['CAB_GDP', 'Public Debt_GDP', 'Public Debt Lag', 'Public Debt Lag Sq', 'Economic result_GDP', 'Primary balance_GDP', 'Primary Balance Lag', 'Fiscal revenue_GDP', 'Government spending_GDP', 'real GDP growth', 'Inflation', 'Interest_GDP', 'Output_Gap']]
df
# Out:
#                   CAB_GDP  Public Debt_GDP  Public Debt Lag  \
# Country     Year
# Afghanistan 2002   33.908          345.977              NaN
#             2003   29.616          270.602          345.977
#             2004   37.216          244.967          270.602
#             2005   30.226          206.356          244.967
#             2006   20.844           22.985          206.356
# ...                   ...              ...              ...
# Zimbabwe    2017   -1.268           74.075           49.892
#             2018   -3.734           51.001           74.075
#             2019    3.536           82.338           51.001
#             2020    2.524           84.448           82.338
#             2021    0.968           59.807           84.448
#
#                   Public Debt Lag Sq  Economic result_GDP  \
# Country     Year
# Afghanistan 2002                 NaN               -0.098
#             2003       119700.084529               -2.102
# ...

# %%
#Visualization of some key variables
fig = plt.figure(figsize = (30,15))

ax1 = fig.add_subplot(151)
ax2 = fig.add_subplot(152)
ax3 = fig.add_subplot(153)
ax4 = fig.add_subplot(154)
ax5 = fig.add_subplot(155)

ax1.scatter(df['Primary balance_GDP'], df['Public Debt Lag'])
ax2.scatter(df['Primary balance_GDP'], df['Interest_GDP'])
ax3.scatter(df['Primary balance_GDP'], df['CAB_GDP'])
ax4.scatter(df['Primary balance_GDP'], df['Inflation'])
ax5.scatter(df['Primary balance_GDP'], df['Output_Gap'])

ax1.set_title('Primary Balance vs Public Debt')
ax1.set_xlabel('Primary Balance')
ax1.set_ylabel('Public Debt')

ax2.set_title('Primary Balance vs Interest Payment')
ax2.set_xlabel('Primary Balance')
ax2.set_ylabel('Interest Payments')

ax3.set_title('Primary Balance vs Current Account')
ax3.set_xlabel('Primary Balance')
ax3.set_ylabel('Current Account')

ax4.set_title('Primary Balance vs Inflation')
ax4.set_xlabel('Primary Balance')
ax4.set_ylabel('Inflation')

ax5.set_title('Primary Balance vs Output Gap')
ax5.set_xlabel('Primary Balance')
ax5.set_ylabel('Output Gap')


plt.show()

# %% [markdown]
# The visualization reveals that some countries in the database have outlier values for some key variables (i.e. Public debt close to 600% of GDP, negative and sizeable interest payments, very sizeable current account surpluses or deficits, higher inflation, among others). In some cases, this is the result of a country's size relative to the rest of the world (i.e. sizeable trade flows with bigger economies), while in others it might be a result of a crisis). These details should be analyzed carefully if one is using the complete database, in order to evaluate the relevance of removing the outliers.
#
# For the purepose of this piece of work, as related to the fiscal reaction function literature and public debt sustainability, we subset the database to account for BRICS nations (Brazil, Russia, India, China, South Africa) and carry on with the empirical work. However, with properly explained and detailed criteria, the following analysis can be extended to other segmentations such as geographical regions (North America, South America, Europe, Africa, Asia, etc) or credit ratings (one would need to construct a variable reflecting the long-term external-debt rating for each country and each year, according to one credit rating agency).

# %%
#Subsetting the dataframe to the BRICS nations for the relevant years.
nyears = list(range(2001,2022))

BRICS_nations = ['Brazil', 'Russia', 'India', 'China', 'South Africa']

#Actual subsetting
BRICS = df.loc[(BRICS_nations, nyears), :]
BRICS = BRICS.sort_index(level = ['Country', 'Year'])

#Checking that we have no missing observations
print(BRICS.isna().sum())

BRICS

#At this point, the election year dummy could manually be created for the BRICS nations. **Pending**
# Out:
# CAB_GDP                    0
# Public Debt_GDP            0
# Public Debt Lag            0
# Public Debt Lag Sq         0
# Economic result_GDP        0
# Primary balance_GDP        0
# Primary Balance Lag        0
# Fiscal revenue_GDP         0
# Government spending_GDP    0
# real GDP growth            0
# Inflation                  0
# Interest_GDP               0
# Output_Gap                 0
# dtype: int64
#                    CAB_GDP  Public Debt_GDP  Public Debt Lag  \
# Country      Year
# Brazil       2001   -4.445           70.054           65.561
#              2002   -1.845           78.798           70.054
#              2003    0.393           73.823           78.798
#              2004    1.339           70.077           73.823
#              2005    1.310           68.585           70.077
# ...                    ...              ...              ...
# South Africa 2017   -2.368           48.588           47.134
# ...

# %%
#For descriptive purposes, we now visualize the same scatter graphs for these variables
fig2 = plt.figure(figsize = (30,15))

ax1 = fig2.add_subplot(151)
ax2 = fig2.add_subplot(152)
ax3 = fig2.add_subplot(153)
ax4 = fig2.add_subplot(154)
ax5 = fig2.add_subplot(155)

ax1.scatter(BRICS['Primary balance_GDP'], BRICS['Public Debt Lag'])
ax2.scatter(BRICS['Primary balance_GDP'], BRICS['Interest_GDP'])
ax3.scatter(BRICS['Primary balance_GDP'], BRICS['CAB_GDP'])
ax4.scatter(BRICS['Primary balance_GDP'], BRICS['Inflation'])
ax5.scatter(BRICS['Primary balance_GDP'], BRICS['Output_Gap'])

ax1.set_title('Primary Balance vs Public Debt')
ax1.set_xlabel('Primary Balance')
ax1.set_ylabel('Public Debt')

ax2.set_title('Primary Balance vs Interest Payment')
ax2.set_xlabel('Primary Balance')
ax2.set_ylabel('Interest Payments')

ax3.set_title('Primary Balance vs Current Account')
ax3.set_xlabel('Primary Balance')
ax3.set_ylabel('Current Account')

ax4.set_title('Primary Balance vs Inflation')
ax4.set_xlabel('Primary Balance')
ax4.set_ylabel('Inflation')

ax5.set_title('Primary Balance vs Output Gap')
ax5.set_xlabel('Primary Balance')
ax5.set_ylabel('Output Gap')


plt.show()

# %% [markdown]
# **5. Empirical Results and Discussion**

# %%
#Descriptive Statistics
BRICS.describe()
# Out:
#           CAB_GDP  Public Debt_GDP  Public Debt Lag  Public Debt Lag Sq  \
# count  105.000000       105.000000       105.000000          105.000000
# mean     0.617981        48.687933        47.957638         2882.156680
# std      3.896322        24.904188        24.244998         2367.767942
# min     -5.326000         7.446000         7.446000           55.442916
# 25%     -2.435000        26.995000        26.995000          728.730025
# 50%      0.246000        48.588000        47.134000         2221.613956
# 75%      2.598000        69.669000        69.000000         4761.000000
# max     10.320000        96.840000        96.840000         9377.985600
#
#        Economic result_GDP  Primary balance_GDP  Primary Balance Lag  \
# count           105.000000           105.000000           105.000000
# mean             -3.566933            -0.673352            -0.530495
# std               4.117844             3.367332             3.441561
# ...

# %% [markdown]
# The above table displays the summary statistics specific to BRICS nations for the ratio of primary balance to GDP, debt-to-GDP ratio, the current account balance as a percentage of GDP, the interest payments as a percentage of GDP, the output gap (as our business cycle indicator variable), headline inflation, among other variables. The mean value for the primary balance as a percentage of GDP is -0.67%, whereas for the debt-to-GDP ratio it is 48.7%.

# %%
#Panel Unit Root Testing
#Package pending for application

# %%
#Cross sectional dependence and heterocedasticity
#Coding pending

# %%
#Estimating the fixed effect baseline model - Important: the outer index must reflect entity, while the inner index must be the time index
fe_mod = PanelOLS(BRICS['Primary balance_GDP'], BRICS[['Primary Balance Lag', 'Public Debt Lag', 'Interest_GDP', 'CAB_GDP', 'Inflation', 'Output_Gap']], entity_effects = True, time_effects = False)
res1 = fe_mod.fit(cov_type = 'clustered', cluster_entity = True)
print(res1)
# Out:
#                            PanelOLS Estimation Summary
# ...
# Dep. Variable:     Primary balance_GDP   R-squared:                        0.5557
# Estimator:                    PanelOLS   R-squared (Between):             -0.0900
# No. Observations:                  105   R-squared (Within):               0.5557
# Date:                 Tue, Jun 13 2023   R-squared (Overall):              0.3451
# Time:                         20:01:14   Log-likelihood                   -214.73
# Cov. Estimator:              Clustered
#                                          F-statistic:                      19.595
# Entities:                          156   P-value                           0.0000
# Avg Obs:                        0.6731   Distribution:                    F(6,94)
# Min Obs:                        0.0000
# Max Obs:                        21.000   F-statistic (robust):            4.1e+16
#                                          P-value                           0.0000
# ...

# %%
#Estimating the random effects baseline model
#Pending

# %%
#Further tests to be carried out
#Haussman

# %% [markdown]
# **References**
#
# Abiad, A., & Baig, T. (2005). Underlying Factors Driving Fiscal Efforts in Emerging Market Economies. International Monetary Fund.
#
# Blanchard, O. (2019). Public Debt and Low Interest Rates. American Economic Review, 1197-1229.
#
# Bohn, H. (1998). The Behavior of U.S. Public Debt and Deficits. The Quarterly Journal of Economics, 949-963.
#
# Bond, S. (2002). Dynamic panel data models: a guide to micro data methods and practice. Portuguese Economic Journal, 141-162.
#
# Escolano, J. (2010). A practical guide to public debt dynamics, fiscal sustainability, and cyclical adjustments of budgetary aggregates. International Monetary Fund.
#
# Ghosh, A., Kim, J., Mendoza, E., Ostry, J., & Qureshi, M. (2013). Fiscal Fatigue, Fiscal Space and Debt Sustainability in Advanced Economies. The Economic Journal, F4-F30.
#
# Ghulam, Y., & Derber, J. (2018). Determinants of Sovereign Default. The Quarterly Review of Economics and Finance, 43-55.
#
# International Monetary Fund. (2022). Staff Guidance Note on the Sovereign Risk and Debt Sustainability Framework for Market Access Countries. International Monetary Fund.
#
# International Monetary Fund. (2023). World Economic Outlook - April 2023: A Rocky Recovery. International Monetary Fund.
#
# Joy, J., & Panda, P. (2020). An empirical analysis of sustainability of public debt among BRICS nations. Journal of Public Affairs, e2170.
#
# Kose, M., Nagle, P., Ohnsorge, F., & Sugawara, N. (2021). What has been the impact of COVID-19 on Debt? World Bank.
#
# Manasse, P., & Roubini, N. (2009). "Rules of Thumb" for sovereign debt crises. Journal of International Economics, 192-205.
#
# Martinez, L., Roch, F., Roldan, F., & Zettlemeyer, J. (2022). Sovereign Debt. IMF.
#
# Ogbeifun, L., & Shobande, O. (2020). Debt Sustainability and the fiscal reaction function: evidence from MIST countries. Future Business Journal.
#
# Panizza, U., Sturzenegger, F., & Zettlemeyer, J. (2012). International Government Debt. In G. Caprio, T. Beck, S. Cleassens, & S. Schmukler, The Evidence and Impact of Financial Globalization (pp. 239-255). Academic Press.
#
# Pesaran, M. (2007). A simple panel unit root test in the presence of cross-section dependence. Journal of Applied Econometrics, 265-312.
#
# Reinhart, C., & Rogoff, K. (2009). This time is different: Eight Centuries of Financial Folly. Princeton: Princeton University Press.
#
# Reinhart, C., & Rogoff, K. (2011). From Financial Crash to Debt Crises. American Economic Review 101, 1676-1706.
#
# Reis, R. (2022). Debt Revenue and the Sustainability of Public Debt. Journal of Economic Perspectives, 103-124.
#
# Willems, T., & Zettlemeyer, J. (2022). Sovereign Debt Sustainability and Central Bank Credibility. Annual Review of Financial Economics, 75-93.
